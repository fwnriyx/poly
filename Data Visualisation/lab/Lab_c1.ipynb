# %%
import pandas as pd

world_pop = pd.read_csv('../DAVI Dataset/world_population.csv', index_col=0)
print(world_pop.head(5))
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Aruba                 ABW  Population density (people per sq. km of land ...
# Andorra               AND  Population density (people per sq. km of land ...
# Afghanistan           AFG  Population density (people per sq. km of land ...
# Angola                AGO  Population density (people per sq. km of land ...
# Albania               ALB  Population density (people per sq. km of land ...
#
#              Indicator Code  1960        1961        1962        1963  \
# Country Name
# Aruba           EN.POP.DNST   NaN  307.972222  312.366667  314.983333
# Andorra         EN.POP.DNST   NaN   30.587234   32.714894   34.914894
# Afghanistan     EN.POP.DNST   NaN   14.038148   14.312061   14.599692
# Angola          EN.POP.DNST   NaN    4.305195    4.384299    4.464433
# Albania         EN.POP.DNST   NaN   60.576642   62.456898   64.329234
#
# ...

# %%
import pandas as pd

world_pop = pd.read_csv('../DAVI Dataset/world_population.csv', index_col=0)
#Question 2s
row3 = world_pop.iloc[[2]].mean(axis = 1, numeric_only = True)
print(row3)
finalRow = world_pop.iloc[[-1]]
print(finalRow.mean(axis = 1, numeric_only = True))
print(world_pop.mean(axis = 1, numeric_only = True).loc["Austria"])

#Question 3s
print(world_pop.median(axis = 1, numeric_only = True).iloc[-1])
print(world_pop[-3:].median(axis = 1, numeric_only = True))
print(world_pop[0:9].median(axis = 1, numeric_only = True))
# Out:
# Country Name
# Afghanistan    25.373379
# dtype: float64
# Country Name
# Zimbabwe    24.520532
# dtype: float64
# 94.31767804292919
# 25.5054310456249
# Country Name
# Congo, Dem. Rep.    14.419050
# Zambia              10.352668
# Zimbabwe            25.505431
# dtype: float64
# Country Name
# Aruba                   348.022222
# Andorra                 107.300000
# Afghanistan              19.998926
# Angola                    8.458253
# Albania                 106.001058
# Arab World               15.307283
# United Arab Emirates     19.305072
# Argentina                11.618238
# Armenia                 105.898033
# dtype: float64

# %%
#Activity 2
import pandas as pd

world_pop = pd.read_csv('../DAVI Dataset/world_population.csv', index_col=0)

a = world_pop.filter(items=['2000','2015'])

print(a)
# Out:
#                         2000        2015
# Country Name
# Aruba             504.766667  577.161111
# Andorra           139.146809  149.942553
# Afghanistan        30.177894   49.821649
# Angola             12.078798   20.070565
# Albania           112.738212  105.444051
# ...                      ...         ...
# Yemen, Rep.        33.704981   50.821477
# South Africa       36.271010   45.303251
# Congo, Dem. Rep.   21.194356   34.082536
# Zambia             14.239121   21.807890
# Zimbabwe           32.312217   40.332819
#
# [264 rows x 2 columns]

# %%
df = pd.read_csv('../DAVI Dataset/world_population.csv', index_col = 0)

b = df[df["2000"]>500][["2000"]]
print(b)
# Out:
#                                    2000
# Country Name
# Aruba                        504.766667
# Bangladesh                  1008.532988
# Bahrain                      939.232394
# Bermuda                     1236.660000
# Barbados                     627.530233
# Channel Islands              766.623711
# Gibraltar                   2735.100000
# Hong Kong SAR, China        6347.619048
# Macao SAR, China           21595.350000
# St. Martin (French part)     521.764706
# Monaco                     16040.500000
# Maldives                     953.333333
# Malta                       1191.759375
# Mauritius                    584.666502
# Nauru                        502.100000
# Singapore                   6011.771642
# Sint Maarten (Dutch part)    897.617647

# %%
df = pd.read_csv('../DAVI Dataset/world_population.csv', index_col=0)

df.filter(like="land", axis=0)
# Out:
#                             Country Code  \
# Country Name
# Switzerland                          CHE
# Channel Islands                      CHI
# Cayman Islands                       CYM
# Finland                              FIN
# Faroe Islands                        FRO
# Greenland                            GRL
# Ireland                              IRL
# Iceland                              ISL
# Marshall Islands                     MHL
# Northern Mariana Islands             MNP
# Netherlands                          NLD
# New Zealand                          NZL
# Poland                               POL
# Pacific island small states          PSS
# Solomon Islands                      SLB
# Swaziland                            SWZ
# Turks and Caicos Islands             TCA
# Thailand                             THA
# British Virgin Islands               VGB
# Virgin Islands (U.S.)                VIR
#
# ...

# %%
df.sort_values(by=["2015"])[["2015"]]
# Out:
#                           2015
# Country Name
# Greenland             0.136713
# Mongolia              1.904744
# Namibia               2.986590
# Australia             3.095579
# Iceland               3.299980
# ...                        ...
# Monaco            18865.500000
# Macao SAR, China  19392.937294
# Eritrea                    NaN
# Not classified             NaN
# South Sudan                NaN
#
# [264 rows x 1 columns]

# %%
df.sort_values(by = ["2015"], ascending = False)[["2015"]]
# Out:
#                               2015
# Country Name
# Macao SAR, China      19392.937294
# Monaco                18865.500000
# Singapore              7828.857143
# Hong Kong SAR, China   6957.809524
# Gibraltar              3221.700000
# ...                            ...
# Mongolia                  1.904744
# Greenland                 0.136713
# Eritrea                        NaN
# Not classified                 NaN
# South Sudan                    NaN
#
# [264 rows x 1 columns]

# %%
df_2015 = df[["Country Code","2015"]]
df_2015.pivot(index=["2015"] * len(df_2015), columns="Country Code", values="2015")
# Out:
# Country Code                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...
